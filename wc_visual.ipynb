# %%
from data_cleaner import stopwords_corpus
from fetch_speech_to_df import spoke_persons
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from sentiment_analysis import create_barplot

wc = WordCloud()

for i in range(4):
    wc.generate(stopwords_corpus.speeches[i])
    plt.imshow(wc, interpolation='bilinear')
    plt.axis("off")
    plt.title(spoke_persons[i])
    plt.show()

# %%
from data_cleaner import stopwords_corpus
from sentiment_analysis import add_sentiment_to_df
from sentida import Sentida
import numpy as np
import matplotlib.pyplot as plt

def create_barplot_total():
    
    plt.figure(figsize=(10, 5))
    plt.bar(stopwords_corpus.index, stopwords_corpus.total)
    plt.xlabel("Speaker")
    plt.ylabel("Sentiment Value")
    plt.title("Total")
    plt.show()

add_sentiment_to_df()
create_barplot_total()

# %%
from data_cleaner import stopwords_corpus
from sentiment_analysis import add_sentiment_to_df
from sentida import Sentida
import numpy as np
import matplotlib.pyplot as plt

def create_barplot_mean():
    
    plt.figure(figsize=(10, 5))
    plt.bar(stopwords_corpus.index, stopwords_corpus.mean)
    plt.xlabel("Speaker")
    plt.ylabel("Sentiment Value")
    plt.title("Mean")
    plt.show()

add_sentiment_to_df()
create_barplot_mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-80c953ced9be> in <module>
#      15
#      16 add_sentiment_to_df()
# ---> 17 create_barplot_mean()
#
# <ipython-input-66-80c953ced9be> in create_barplot_mean()
#       8
#       9     plt.figure(figsize=(10, 5))
# ---> 10     plt.bar(stopwords_corpus.index, stopwords_corpus.mean)
#      11     plt.xlabel("Speaker")
#      12     plt.ylabel("Sentiment Value")
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2407     return gca().bar(
#    2408         x, height, width=width, bottom=bottom, align=align,
# -> 2409         **({"data": data} if data is not None else {}), **kwargs)
#    2410
#    2411
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2393                 edgecolor=e,
#    2394                 linewidth=lw,
# -> 2395                 label='_nolegend_',
#    2396                 )
#    2397             r.update(kwargs)
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/patches.py in __init__(self, xy, width, height, angle, **kwargs)
#     734
#     735         self._x1 = self._x0 + self._width
# --> 736         self._y1 = self._y0 + self._height
#     737
#     738         self.angle = float(angle)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'method'
